# %%
import pandas as pd
import numpy as np
import langchain
from langchain_huggingface import HuggingFaceEmbeddings
from pinecone import Pinecone
from langchain_pinecone import PineconeVectorStore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       4 from langchain_huggingface import HuggingFaceEmbeddings
#       5 from pinecone import Pinecone
# ----> 6 from langchain_pinecone import PineconeVectorStore
#
# ModuleNotFoundError: No module named 'langchain_pinecone'

# %%
# !pip3 install -qU langchain-pinecone==0.1.2
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.0.2 Requires-Python >=3.8.1,<3.13; 0.0.2rc0 Requires-Python >=3.8.1,<3.13; 0.0.3 Requires-Python >=3.8.1,<3.13; 0.1.0 Requires-Python >=3.8.1,<3.13; 0.1.1 Requires-Python >=3.8.1,<3.13; 0.1.2 Requires-Python >=3.8.1,<3.13; 0.1.3 Requires-Python >=3.8.1,<3.13; 0.2.0 Requires-Python >=3.9,<3.13; 0.2.0.dev1 Requires-Python >=3.9,<3.13; 0.2.1 Requires-Python >=3.9,<3.13; 0.2.10 Requires-Python >=3.9,<3.14; 0.2.11 Requires-Python >=3.9,<3.14; 0.2.12 Requires-Python >=3.9,<3.14; 0.2.13 Requires-Python >=3.9,<3.14; 0.2.13rc1 Requires-Python >=3.9,<3.14; 0.2.2 Requires-Python >=3.9,<3.13; 0.2.3 Requires-Python >=3.9,<3.14; 0.2.4 Requires-Python >=3.9,<3.14; 0.2.4rc1 Requires-Python >=3.9,<3.14; 0.2.4rc2 Requires-Python >=3.9,<3.14; 0.2.5 Requires-Python >=3.9,<3.14; 0.2.5rc1 Requires-Python >=3.9,<3.14; 0.2.6 Requires-Python >=3.9,<3.14; 0.2.7 Requires-Python >=3.9,<3.14; 0.2.8 Requires-Python >=3.9,<3.14; 0.2.9 Requires-Python >=3.9,<3.14
# ERROR: Could not find a version that satisfies the requirement langchain-pinecone==0.1.2 (from versions: 0.0.1)
# ERROR: No matching distribution found for langchain-pinecone==0.1.2

# %%
# !pip3 install simsimd==6.5.0
# Out:
# Collecting simsimd==6.5.0
#   Downloading simsimd-6.5.0.tar.gz (172 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: simsimd
#   Building wheel for simsimd (pyproject.toml) ... done
#   Created wheel for simsimd: filename=simsimd-6.5.0-cp314-cp314-macosx_10_15_universal2.whl size=235960 sha256=5b132ff6dbbc9d20d48f987f87ddd6344bcb7aeb1121509655d8c63222b9873e
#   Stored in directory: /Users/archishman/Library/Caches/pip/wheels/db/9e/e8/8e946ee389463cf2b0343ce3dcd28a3fd33bde7decd598157a
# Successfully built simsimd
# Installing collected packages: simsimd
# Successfully installed simsimd-6.5.0

# %%
pc = Pinecone(api_key=pinecone_api_key)
index = pc.Index("bits-project-index")

# %%
# embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
